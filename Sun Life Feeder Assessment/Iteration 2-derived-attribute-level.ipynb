# %%
import pandas as pd

df = pd.read_excel('Output0325.xlsx', index_col=0)
df
# Out:
#                                       BU SourceSystem   PRKey  \
# BG
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# US                        Group Benefits      Compass  UE.TXT
# ..                                   ...          ...     ...
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
# US  Individual International Reinsurance       Vision  R2.TXT
#
#            FeedType    Typename  \
# BG
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# US  New file layout  New US TBF
# ..              ...         ...
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
# US     Current feed       FRVLJ
#
#                        FinancialReportingRequirements  SumofAttributesUsed  \
# BG
# US                                          Portfolio                  NaN
# US                              PAS System Identifier                  NaN
# US  How to uniquely identify contract under IFRS 1...                  NaN
# US  Date contract was issued (i.e. policy / benefi...                  NaN
# US  Date contract matures (i.e. policy / benefit m...                  NaN
# US                                     Cohort / Group                  NaN
# US  Cash flow indicator (Cash / Accrual / Adjustme...                  NaN
# US    Account: Premiums (first year, renewal, single)                  NaN
# US        Account: Claims (e.g. Death, Annuity, etc.)                  NaN
# US  Account: Investment Component (how you identif...                  NaN
# US   Account: Directly Attributable Acquisition Costs                  NaN
# US  Conversions: Indicator that policy is result o...                  NaN
# US  Conversions: Old Policy or Contract Number and...                  NaN
# US                          Reinsurance: Counterparty                  NaN
# US                             Reinsurance: Treaty ID                  NaN
# US              Reinsurance: Direct underlying policy                  NaN
# US  Reinsurance: Date of initial recognition of ce...                  NaN
# US  Expense Indicator to distinguish between Maint...                  NaN
# US                         Reinsurance Type Indicator                  NaN
# US                                              PRKey                  NaN
# US                                          Source ID                  NaN
# US                                       Legal Entity                  NaN
# US                                Parent Legal Entity                  NaN
# US                            Inter-company Indicator                  NaN
# US  Accounting Bases of Feeds (i.e. IFRS 4, IFRS 1...                  NaN
# US                                  Chart of Accounts                  NaN
# US                                         Basis Code                  NaN
# US                                     Account Number                  NaN
# US                                     Debit / Credit                  NaN
# US                                             Amount                  NaN
# ..                                                ...                  ...
# US                             Bank Disbursement Date                  NaN
# US                                Disbursement Number                  NaN
# US                               JID_PR_KEY + Segment                  NaN
# US                                     Effective Date                  NaN
# US                                      Currency code                  NaN
# US                                              PRKey                  NaN
# US                        Major Product (segment/lob)                  NaN
# US                                     Account Number                  NaN
# US                                        Cost Center                  NaN
# US                                              Issue                  NaN
# US                                          Residence                  NaN
# US                                     Debit / Credit                  NaN
# US                                             Amount                  NaN
# US                                      Reversal Date                  NaN
# US                        Legacy System Reference Key                  NaN
# US                                       Municipality                  NaN
# US                                  Free format field                  NaN
# US                                              APPDT                  NaN
# US                                        Record Code                  NaN
# US                                     Company number                  NaN
# US                                      Policy number                  NaN
# US                                       Check number                  NaN
# US                                       Agent number                  NaN
# US                                           Zip code                  NaN
# US                                           Batch ID                  NaN
# US                                          Plan Code                  NaN
# US                                         Issue Date                  NaN
# US                                Original Issue Date                  NaN
# US                                               City                  NaN
# US                                            Address                  NaN
#
#                    Reqcategory DetailedCategory_forAdditionalAttributesonly  \
# BG
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US                     IFRS 17                                          NaN
# US  GL Accounting Requirements                                          NaN
# US  GL Accounting Requirements                                          NaN
# US       Additional Accounting                                          NaN
# US  GL Accounting Requirements                                          NaN
# US        Additional Reporting                                          NaN
# US  GL Accounting Requirements                                          NaN
# US  GL Accounting Requirements                                          NaN
# US       Additional Accounting                                          NaN
# US        Additional Reporting                                          NaN
# US  GL Accounting Requirements                                          NaN
# US  GL Accounting Requirements                                          NaN
# US  GL Accounting Requirements                                          NaN
# ..                         ...                                          ...
# US         Banking Information                                          NaN
# US         Banking Information                                          NaN
# US        Additional Reporting                                          NaN
# US  GL Accounting Requirements                                          NaN
# US  GL Accounting Requirements                                          NaN
# US        Additional Reporting                                          NaN
# US  GL Accounting Requirements                                          NaN
# US  GL Accounting Requirements                                          NaN
# US  GL Accounting Requirements                                          NaN
# US  GL Accounting Requirements                                          NaN
# US  GL Accounting Requirements                                          NaN
# US  GL Accounting Requirements                                          NaN
# US  GL Accounting Requirements                                          NaN
# US  GL Accounting Requirements                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
# US        Additional Reporting                                          NaN
#
#    AssumedStrategytoMeetRequirements_forIFRS17reportingrequirementsGLAccountingonly  \
# BG
# US  Assumed will not be provided by feeder but wil...
# US  Either provided by feeder or derived from feed...
# US  Derived from Policy / Benefit Number / Unique ...
# US  Assumed will not be provided by feeder but wil...
# US  Assumed will not be provided by feeder but wil...
# US  Assumed will not be provided in feeder but wil...
# US             Assumed will be provided by the feeder
# US  Assumed can be derived by data provided by feeder
# US  Assumed can be derived by data provided by feeder
# US  Assumed can be derived by data provided by feeder
# US  Assumed can be derived by data provided by feeder
# US  No portabiity and/or conversion members on Com...
# US  No portabiity and/or conversion members on Com...
# US  Treaty data fed separately.\nJoined by Policy ...
# US  Treaty data fed separately.\nJoined by Policy ...
# US  Treaty data fed separately.\nJoined by Policy ...
# US  Treaty data fed separately.\nJoined by Policy ...
# US  Working assumption is the Expense Indicator wi...
# US  Assumed can be derived by data provided by feeder
# US                    Value assigned by feeder system
# US                    Value assigned by feeder system
# US                    Value assigned by feeder system
# US                    Value assigned by feeder system
# US                    Value assigned by feeder system
# US                    Value assigned by feeder system
# US                    Value assigned by feeder system
# US                    Value assigned by feeder system
# US                    Value assigned by feeder system
# US                    Value assigned by feeder system
# US                    Value assigned by feeder system
# ..                                                ...
# US  If feed sends banking info, assumption that it...
# US                                                NaN
# US                                                NaN
# US  Assumed can be derived by data provided by feeder
# US  Assumed can be derived by data provided by feeder
# US                                                NaN
# US  Assumed can be derived by data provided by feeder
# US  Assumed can be derived by data provided by fee...
# US  Assumed can be derived by data provided by feeder
# US  Assumed can be derived by data provided by feeder
# US  Assumed can be derived by data provided by feeder
# US  Assumed can be derived by data provided by feeder
# US  Assumed can be derived by data provided by feeder
# US  Assumed can be derived by data provided by feeder
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
#
#              ...            Attribute12_AttributeName  \
# BG           ...
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# ..           ...                                  ...
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
# US           ...                                  NaN
#
#    Attribute12_AttributeDefinition_ifnetnewdataattribute  \
# BG
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# ..                                                ...
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
#
#    Attribute12_StrategytoObtainAttribute  \
# BG
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# ..                                   ...
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
# US                                   NaN
#
#    Attribute12_Ifattributewillbederivedhasbusinesslogicbeendefined  \
# BG
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# ..                                                ...
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
#
#    Attribute12_Ifattributewillbederivedwhatreferencedatamappingtablesarerequired  \
# BG
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# ..                                                ...
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
# US                                                NaN
#
#    Attribute12_DataType Attribute12_IfDatewhatisLayout  \
# BG
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# ..                  ...                            ...
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
# US                  NaN                            NaN
#
#     Attribute12_DataLength Attribute12_Nullable Attribute12_Concatenated
# BG
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# ..                     ...                  ...                      ...
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
# US                     NaN                  NaN                      NaN
#
# [2105 rows x 141 columns]

# %%
# summary = pd.DataFrame({'Feed Count': df.groupby(['BG', 'BU', 'Reqcategory', 'Typename', 'FinancialReportingRequirements', 'BUProposedStrategytoMeetRequirements', 'Attribute1_AttributeName', 'Attribute2_AttributeName', 'Attribute3_AttributeName', 'Attribute4_AttributeName', 'Attribute5_AttributeName', 'Attribute6_AttributeName', 'Attribute7_AttributeName'])['Attribute1_AttributeName', 'Attribute2_AttributeName'].count()}).reset_index()
# summary
df.fillna(-1, inplace=True)
df = df.apply(lambda x: x.astype(str).str.lower())
is_derived =  df['BUProposedStrategytoMeetRequirements']=='derived from feed attributes'
summary_derived = df[is_derived]
summary_derived
total_derived = summary_derived.groupby(['FinancialReportingRequirements', 'BUProposedStrategytoMeetRequirements']).size().reset_index(name='Total_Derived')
total_derived = total_derived[['FinancialReportingRequirements', 'Total_Derived']]
total_derived
duplicates = summary_derived.groupby(['Reqcategory', 'FinancialReportingRequirements', 'Attribute1_AttributeName', 'Attribute2_AttributeName', 'Attribute3_AttributeName','Attribute4_AttributeName','Attribute5_AttributeName','Attribute6_AttributeName','Attribute7_AttributeName','Attribute8_AttributeName','Attribute9_AttributeName','Attribute10_AttributeName']).size().reset_index(name='Count')
df_merge_col = pd.merge(duplicates, total_derived, on=['FinancialReportingRequirements'])
df_merge_col
df_merge_col['Percentage'] = df_merge_col['Count'] / df_merge_col['Total_Derived'] * 100
df_merge_col
# Out:
#                    Reqcategory  \
# 0         additional reporting
# 1   gl accounting requirements
# 2         additional reporting
# 3   gl accounting requirements
# 4   gl accounting requirements
# 5   gl accounting requirements
# 6   gl accounting requirements
# 7   gl accounting requirements
# 8   gl accounting requirements
# 9   gl accounting requirements
# 10                     ifrs 17
# 11                     ifrs 17
# 12                     ifrs 17
# 13                     ifrs 17
# 14                     ifrs 17
# 15                     ifrs 17
# 16                     ifrs 17
# 17                     ifrs 17
# 18                     ifrs 17
# 19                     ifrs 17
# 20                     ifrs 17
# 21                     ifrs 17
#
#                        FinancialReportingRequirements  \
# 0                                               issue
# 1                                               issue
# 2                         legacy system reference key
# 3                                      account number
# 4                         major product (segment/lob)
# 5                         major product (segment/lob)
# 6                         major product (segment/lob)
# 7                         major product (segment/lob)
# 8                          reinsurance type indicator
# 9                          reinsurance type indicator
# 10   account: directly attributable acquisition costs
# 11   account: directly attributable acquisition costs
# 12    account: premiums (first year, renewal, single)
# 13    account: premiums (first year, renewal, single)
# 14                                     cohort / group
# 15                                     cohort / group
# 16  expense indicator to distinguish between maint...
# 17  expense indicator to distinguish between maint...
# 18  how to uniquely identify contract under ifrs 1...
# 19                              pas system identifier
# 20                                          portfolio
# 21                                          portfolio
#
#        Attribute1_AttributeName       Attribute2_AttributeName  \
# 0                            -1                             -1
# 1                            -1                             -1
# 2                          corp                        segment
# 3                            -1                             -1
# 4                            -1                             -1
# 5             block of business                      plan type
# 6   major product source code 1                             -1
# 7   major product source code 1    major product source code 2
# 8                            -1                             -1
# 9               policy source 1                policy source 2
# 10                           -1                             -1
# 11               account number                             -1
# 12                           -1                             -1
# 13         participation number   prior renewal effective date
# 14                           -1                             -1
# 15          rate guarantee date   prior renewal effective date
# 16                           -1                             -1
# 17              policy source 1                policy source 2
# 18              policy source 1                policy source 2
# 19                        prkey               source system id
# 20                           -1                             -1
# 21         participation number  benefit id (not in gl format)
#
#        Attribute3_AttributeName     Attribute4_AttributeName  \
# 0                            -1                           -1
# 1                            -1                           -1
# 2                       account                      costctr
# 3                            -1                           -1
# 4                            -1                           -1
# 5                      sub plan                 pooling code
# 6                            -1                           -1
# 7   major product source code 3  major product source code 4
# 8                            -1                           -1
# 9                 major product             source system id
# 10                           -1                           -1
# 11                           -1                           -1
# 12                           -1                           -1
# 13          rate guarantee date    cash vs accrued indicator
# 14                           -1                           -1
# 15             source system id         participation number
# 16                           -1                           -1
# 17                major product             source system id
# 18              policy source 3              policy source 4
# 19                           -1                           -1
# 20                           -1                           -1
# 21             source system id              policy source 1
#
#    Attribute5_AttributeName       Attribute6_AttributeName  \
# 0                        -1                             -1
# 1                        -1                             -1
# 2                       tax                          issue
# 3                        -1                             -1
# 4                        -1                             -1
# 5   dental standard plan id                         ppo id
# 6                        -1                             -1
# 7                        -1                             -1
# 8                        -1                             -1
# 9                        -1                             -1
# 10                       -1                             -1
# 11                       -1                             -1
# 12                       -1                             -1
# 13         source system id         benefit available date
# 14                       -1                             -1
# 15             policy issue                policy source 1
# 16                       -1                             -1
# 17              cost center                             -1
# 18         source system id  benefit id (not in gl format)
# 19                       -1                             -1
# 20                       -1                             -1
# 21          policy source 2                policy source 3
#
#    Attribute7_AttributeName Attribute8_AttributeName Attribute9_AttributeName  \
# 0                        -1                       -1                       -1
# 1                        -1                       -1                       -1
# 2                     resid        source row number                       -1
# 3                        -1                       -1                       -1
# 4                        -1                       -1                       -1
# 5                        -1                       -1                       -1
# 6                        -1                       -1                       -1
# 7                        -1                       -1                       -1
# 8                        -1                       -1                       -1
# 9                        -1                       -1                       -1
# 10                       -1                       -1                       -1
# 11                       -1                       -1                       -1
# 12                       -1                       -1                       -1
# 13          policy source 1          policy source 2          policy source 3
# 14                       -1                       -1                       -1
# 15          policy source 2          policy source 3          policy source 4
# 16                       -1                       -1                       -1
# 17                       -1                       -1                       -1
# 18     participation number                       -1                       -1
# 19                       -1                       -1                       -1
# 20                       -1                       -1                       -1
# 21          policy source 4                       -1                       -1
#
#    Attribute10_AttributeName  Count  Total_Derived  Percentage
# 0                         -1      1              6   16.666667
# 1                         -1      5              6   83.333333
# 2                         -1      1              1  100.000000
# 3                         -1     12             12  100.000000
# 4                         -1     17             21   80.952381
# 5                         -1      2             21    9.523810
# 6                         -1      1             21    4.761905
# 7                         -1      1             21    4.761905
# 8                         -1     10             13   76.923077
# 9                         -1      3             13   23.076923
# 10                        -1      1              3   33.333333
# 11                        -1      2              3   66.666667
# 12                        -1      2              4   50.000000
# 13           policy source 4      2              4   50.000000
# 14                        -1     14             19   73.684211
# 15                        -1      5             19   26.315789
# 16                        -1      4              6   66.666667
# 17                        -1      2              6   33.333333
# 18                        -1      6              6  100.000000
# 19                        -1      1              1  100.000000
# 20                        -1     15             17   88.235294
# 21                        -1      2             17   11.764706

# %%
df_merge_col.to_excel("Derived0325_attribute.xlsx")

# %%
file_types = df.Typename.unique()

file_types
# Out:
# array([u'New US TBF', u'New US Ref Data (Group)',
#        u'New US Ref Data (Benefit)'], dtype=object)

# %%
# counts = df[df['Typename'].isin(["New GB EBF"])].PRKey.count()
# counts
attributes = df.FinancialReportingRequirements.unique()
attributes
attributes_count = {}
for j in file_types:
    nested = {}
    for i in attributes:
        name = df.loc[(df['Typename'].isin([j])) & (df['FinancialReportingRequirements'].isin([i]))]
        nested[i] = name.FinancialReportingRequirements.count()
    attributes_count[j] = nested

attributes_count
# Out:
# {u'New US Ref Data (Benefit)': {u'Account: Claims (e.g. Death, Annuity, etc.)': 0,
#   u'Account: Directly Attributable Acquisition Costs': 0,
#   u'Account: Investment Component (how you identify the investment component of a claim/benefit transaction)': 0,
#   u'Account: Premiums (first year, renewal, single)': 0,
#   u'Cash flow indicator (Cash / Accrual / Adjustment, etc.)': 0,
#   u'Cohort / Group': 0,
#   u'Conversions: Indicator that policy is result of a conversion': 0,
#   u'Conversions: Old Policy or Contract Number and IFRS 17 Group': 0,
#   u'Date contract matures (i.e. policy / benefit maturity date)': 0,
#   u'Date contract was issued (i.e. policy / benefit issue date)': 0,
#   u'Expense Indicator to distinguish between Maintenance/Acquisition and IFRS 17 Attributable/Non-Attributable expenses': 0,
#   u'How to uniquely identify contract under IFRS 17 ? (i.e. policy / benefit number)': 0,
#   u'PAS System Identifier': 0,
#   u'Portfolio': 0,
#   u'Rate Guarantee Period': 1,
#   u'Reinsurance: Counterparty': 0,
#   u'Reinsurance: Date of initial recognition of cession': 0,
#   u'Reinsurance: Direct underlying policy': 0,
#   u'Reinsurance: Treaty ID': 0,
#   u'Renewal Date Next': 1,
#   u'Renewal Date Prior': 1},
#  u'New US Ref Data (Group)': {u'Account: Claims (e.g. Death, Annuity, etc.)': 0,
#   u'Account: Directly Attributable Acquisition Costs': 0,
#   u'Account: Investment Component (how you identify the investment component of a claim/benefit transaction)': 0,
#   u'Account: Premiums (first year, renewal, single)': 0,
#   u'Cash flow indicator (Cash / Accrual / Adjustment, etc.)': 0,
#   u'Cohort / Group': 0,
#   u'Conversions: Indicator that policy is result of a conversion': 0,
#   u'Conversions: Old Policy or Contract Number and IFRS 17 Group': 0,
#   u'Date contract matures (i.e. policy / benefit maturity date)': 0,
#   u'Date contract was issued (i.e. policy / benefit issue date)': 1,
#   u'Expense Indicator to distinguish between Maintenance/Acquisition and IFRS 17 Attributable/Non-Attributable expenses': 0,
#   u'How to uniquely identify contract under IFRS 17 ? (i.e. policy / benefit number)': 0,
#   u'PAS System Identifier': 0,
#   u'Portfolio': 0,
#   u'Rate Guarantee Period': 0,
#   u'Reinsurance: Counterparty': 0,
#   u'Reinsurance: Date of initial recognition of cession': 0,
#   u'Reinsurance: Direct underlying policy': 0,
#   u'Reinsurance: Treaty ID': 0,
#   u'Renewal Date Next': 0,
#   u'Renewal Date Prior': 0},
#  u'New US TBF': {u'Account: Claims (e.g. Death, Annuity, etc.)': 2,
#   u'Account: Directly Attributable Acquisition Costs': 2,
#   u'Account: Investment Component (how you identify the investment component of a claim/benefit transaction)': 2,
#   u'Account: Premiums (first year, renewal, single)': 2,
#   u'Cash flow indicator (Cash / Accrual / Adjustment, etc.)': 2,
#   u'Cohort / Group': 2,
#   u'Conversions: Indicator that policy is result of a conversion': 2,
#   u'Conversions: Old Policy or Contract Number and IFRS 17 Group': 2,
#   u'Date contract matures (i.e. policy / benefit maturity date)': 2,
#   u'Date contract was issued (i.e. policy / benefit issue date)': 2,
#   u'Expense Indicator to distinguish between Maintenance/Acquisition and IFRS 17 Attributable/Non-Attributable expenses': 2,
#   u'How to uniquely identify contract under IFRS 17 ? (i.e. policy / benefit number)': 2,
#   u'PAS System Identifier': 2,
#   u'Portfolio': 2,
#   u'Rate Guarantee Period': 0,
#   u'Reinsurance: Counterparty': 2,
#   u'Reinsurance: Date of initial recognition of cession': 2,
#   u'Reinsurance: Direct underlying policy': 2,
#   u'Reinsurance: Treaty ID': 2,
#   u'Renewal Date Next': 0,
#   u'Renewal Date Prior': 0}}

# %%
summary['Percentage'] = ""
for file_type in attributes_count:
    for key in attributes_count[file_type]:
        new = summary.loc[(summary['Typename'].isin([file_type])) & (summary['FinancialReportingRequirements'].isin([key]))]
        new['Percentage'] = new['Feed Count'] / attributes_count[file_type][key] * 100
        summary.update(new)

summary
# Out:
# C:\Users\Jia.C.Chen\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#    BG              BU Reqcategory    Typename  \
# 0  US  Group Benefits     IFRS 17  New US TBF
# 1  US  Group Benefits     IFRS 17  New US TBF
# 2  US  Group Benefits     IFRS 17  New US TBF
# 3  US  Group Benefits     IFRS 17  New US TBF
# 4  US  Group Benefits     IFRS 17  New US TBF
# 5  US  Group Benefits     IFRS 17  New US TBF
#
#                       FinancialReportingRequirements  \
# 0    Account: Premiums (first year, renewal, single)
# 1                                     Cohort / Group
# 2  Date contract matures (i.e. policy / benefit m...
# 3  Date contract was issued (i.e. policy / benefi...
# 4  How to uniquely identify contract under IFRS 1...
# 5                                          Portfolio
#
#   BUProposedStrategytoMeetRequirements Attribute1_AttributeName  \
# 0         Derived from feed attributes     Participation Number
# 1         Derived from feed attributes      Rate Guarantee Date
# 2                  Reference Data feed          Policy Source 1
# 3                  Reference Data feed          Policy Source 1
# 4         Derived from feed attributes          Policy Source 1
# 5         Derived from feed attributes     Participation Number
#
#         Attribute2_AttributeName Attribute3_AttributeName  \
# 0   Prior Renewal Effective Date      Rate Guarantee Date
# 1   Prior Renewal Effective Date         Source System ID
# 2                Policy Source 2          Policy Source 3
# 3                Policy Source 2          Policy Source 3
# 4                Policy Source 2          Policy Source 3
# 5  Benefit ID (not in GL format)         Source System ID
#
#     Attribute4_AttributeName Attribute5_AttributeName  \
# 0  Cash vs accrued indicator         Source System ID
# 1       Participation Number             Policy Issue
# 2            Policy Source 4         Source System ID
# 3            Policy Source 4         Source System ID
# 4            Policy Source 4         Source System ID
# 5            Policy Source 1          Policy Source 2
#
#         Attribute6_AttributeName Attribute7_AttributeName  Feed Count  \
# 0         Benefit available date          Policy Source 1         1.0
# 1                Policy Source 1          Policy Source 2         1.0
# 2  Benefit ID (not in GL format)     Participation Number         1.0
# 3  Benefit ID (not in GL format)     Participation Number         1.0
# 4  Benefit ID (not in GL format)     Participation Number         1.0
# 5                Policy Source 3          Policy Source 4         1.0
#
#   Percentage
# 0         50
# 1         50
# 2         50
# 3         50
# 4         50
# 5         50

# %%
is_derived =  summary['BUProposedStrategytoMeetRequirements']=='Derived from feed attributes'
summary_derived = summary[is_derived]
summary_derived
# Out:
#     BG              BU Reqcategory    Typename  \
# 6   US  Group Benefits     IFRS 17  New US TBF
# 9   US  Group Benefits     IFRS 17  New US TBF
# 12  US  Group Benefits     IFRS 17  New US TBF
# 20  US  Group Benefits     IFRS 17  New US TBF
# 22  US  Group Benefits     IFRS 17  New US TBF
# 25  US  Group Benefits     IFRS 17  New US TBF
#
#                        FinancialReportingRequirements  \
# 6    Account: Directly Attributable Acquisition Costs
# 9     Account: Premiums (first year, renewal, single)
# 12                                     Cohort / Group
# 20  Expense Indicator to distinguish between Maint...
# 22  How to uniquely identify contract under IFRS 1...
# 25                                          Portfolio
#
#    BUProposedStrategytoMeetRequirements  Feed Count Percentage
# 6          Derived from feed attributes         1.0         50
# 9          Derived from feed attributes         1.0         50
# 12         Derived from feed attributes         1.0         50
# 20         Derived from feed attributes         1.0         50
# 22         Derived from feed attributes         1.0         50
# 25         Derived from feed attributes         1.0         50

# %%
summary.to_excel("summary.xlsx")
