# %%
import pandas as pd

df = pd.read_excel('output1.xlsx', index_col=0)
df
# Out:
#                     BU     SourceSystem   PRKey         FeedType    Typename  \
# BG
# Canada  Group Benefits            Oasis  GF.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  GV.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  GF.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  GF.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  GF.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  GZ.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  GI.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  GU.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  YT.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  AB.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  CD.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  GI.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  GU.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  YT.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  AB.TXT  New file layout  New GB EBF
# Canada  Group Benefits            Oasis  CD.TXT  New file layout  New GB EBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UE.TXT  New file layout  New US TBF
# ...                ...              ...     ...              ...         ...
# US      Group Benefits          Compass  UH.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UH.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UH.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UH.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UH.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UH.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UH.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UH.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UH.TXT  New file layout  New US TBF
# US      Group Benefits          Compass  UH.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
# US      Group Benefits  Groupfacts (GF)  UU.TXT  New file layout  New US TBF
#
#                            FinancialReportingRequirements  \
# BG
# Canada                                          Portfolio
# Canada                                          Portfolio
# Canada                                          Portfolio
# Canada                                          Portfolio
# Canada                                          Portfolio
# Canada                                          Portfolio
# Canada                                          Portfolio
# Canada                                          Portfolio
# Canada                                          Portfolio
# Canada                                          Portfolio
# Canada                                          Portfolio
# Canada                                             Cohort
# Canada                                             Cohort
# Canada                                             Cohort
# Canada                                             Cohort
# Canada                                             Cohort
# US                                              Portfolio
# US                                  PAS System Identifier
# US      How to uniquely identify contract? (i.e. polic...
# US      Date contract was issued (i.e. policy / benefi...
# US      Date contract matures (i.e. policy / benefit m...
# US                                         Cohort / Group
# US      Cash flow indicator (Cash / Accrual / Adjustme...
# US        Account: Premiums (first year, renewal, single)
# US            Account: Claims (e.g. Death, Annuity, etc.)
# US                          Account: Investment Component
# US       Account: Directly Attributable Acquisition Costs
# US      Conversions: Indicator that policy is result o...
# US      Conversions: Old Policy or Contract Number and...
# US                              Reinsurance: Counterparty
# ...                                                   ...
# US                            Associated Payee State Code
# US                                    Claim incurral date
# US           Claims reported date (aka claims start date)
# US                                  Benefit election date
# US                                      period start date
# US                                        period end date
# US                                      Billing frequency
# US                                 Skip billing indicator
# US                                 Skip period start date
# US                                   Skip period end date
# US                                              Portfolio
# US                                  PAS System Identifier
# US      How to uniquely identify contract? (i.e. polic...
# US      Date contract was issued (i.e. policy / benefi...
# US      Date contract matures (i.e. policy / benefit m...
# US                                         Cohort / Group
# US      Cash flow indicator (Cash / Accrual / Adjustme...
# US        Account: Premiums (first year, renewal, single)
# US            Account: Claims (e.g. Death, Annuity, etc.)
# US                          Account: Investment Component
# US       Account: Directly Attributable Acquisition Costs
# US      Conversions: Indicator that policy is result o...
# US      Conversions: Old Policy or Contract Number and...
# US                              Reinsurance: Counterparty
# US                                 Reinsurance: Treaty ID
# US                  Reinsurance: Direct underlying policy
# US      Reinsurance: Date of initial recognition of ce...
# US                                      Expense Indicator
# US                             Reinsurance Type Indicator
# US                                                  PRKey
#
#         SumofAttributesUsed                 Reqcategory  \
# BG
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# Canada                  NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# ...                     ...                         ...
# US                      NaN        Additional Reporting
# US                      NaN        Additional Reporting
# US                      NaN        Additional Reporting
# US                      NaN        Additional Reporting
# US                      NaN        Additional Reporting
# US                      NaN        Additional Reporting
# US                      NaN        Additional Reporting
# US                      NaN        Additional Reporting
# US                      NaN        Additional Reporting
# US                      NaN        Additional Reporting
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN                     IFRS 17
# US                      NaN  GL Accounting Requirements
# US                      NaN  GL Accounting Requirements
#
#        DetailedCategory_forAdditionalAttributesonly  \
# BG
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# Canada                                          NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# ...                                             ...
# US                                        Statutory
# US                                       Management
# US                                        Statutory
# US                                        Statutory
# US                                        Statutory
# US                                        Statutory
# US                                        Statutory
# US                                        Statutory
# US                                        Statutory
# US                                        Statutory
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
# US                                              NaN
#
#        AssumedStrategytoMeetRequirements_forIFRS17reportingrequirementsGLAccountingonly  \
# BG
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# US      Assumed will not be provided by feeder but wil...
# US      Either provided by feeder or derived from feed...
# US      Derived from Policy / Benefit Number / Unique ...
# US      Assumed will not be provided by feeder but wil...
# US      Assumed will not be provided by feeder but wil...
# US      Assumed will not be provided in feeder but wil...
# US                 Assumed will be provided by the feeder
# US      Assumed can be derived by data provided by feeder
# US      Assumed can be derived by data provided by feeder
# US      Assumed can be derived by data provided by feeder
# US      Assumed can be derived by data provided by feeder
# US      No portabiity and/or conversion members on Com...
# US      No portabiity and/or conversion members on Com...
# US      Treaty data fed separately.\nJoined by Policy ...
# ...                                                   ...
# US                        Value assigned by feeder system
# US                               Leave blank for UH feed.
# US                               Leave blank for UH feed.
# US                               Leave blank for UH feed.
# US                        Value assigned by feeder system
# US                        Value assigned by feeder system
# US                        Value assigned by feeder system
# US                        Value assigned by feeder system
# US                        Value assigned by feeder system
# US                        Value assigned by feeder system
# US      Assumed will not be provided by feeder but wil...
# US      Either provided by feeder or derived from feed...
# US      Derived from Policy / Benefit Number / Unique ...
# US      Assumed will not be provided by feeder but wil...
# US      Assumed will not be provided by feeder but wil...
# US      Assumed will not be provided in feeder but wil...
# US                 Assumed will be provided by the feeder
# US      Assumed can be derived by data provided by feeder
# US      Assumed can be derived by data provided by feeder
# US      Assumed can be derived by data provided by feeder
# US      Assumed can be derived by data provided by feeder
# US      No portabiity and/or conversion members on GF ...
# US      No portabiity and/or conversion members on GF ...
# US      Treaty data fed separately.\nJoined by Policy ...
# US      Treaty data fed separately.\nJoined by Policy ...
# US      Treaty data fed separately.\nJoined by Policy ...
# US      Treaty data fed separately.\nJoined by Policy ...
# US      Working assumption is the Expense Indicator wi...
# US      Assumed can be derived by data provided by feeder
# US                        Value assigned by feeder system
#
#                  ...            Attribute12_AttributeName  \
# BG               ...
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# Canada           ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# ...              ...                                  ...
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
# US               ...                                  NaN
#
#        Attribute12_AttributeDefinition_ifnetnewdataattribute  \
# BG
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# ...                                                   ...
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
#
#        Attribute12_StrategytoObtainAttribute  \
# BG
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# Canada                                   NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# ...                                      ...
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
# US                                       NaN
#
#        Attribute12_Ifattributewillbederivedhasbusinesslogicbeendefined  \
# BG
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# ...                                                   ...
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
#
#        Attribute12_Ifattributewillbederivedwhatreferencedatamappingtablesarerequired  \
# BG
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# Canada                                                NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# ...                                                   ...
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
# US                                                    NaN
#
#        Attribute12_DataType Attribute12_IfDatewhatisLayout  \
# BG
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# Canada                  NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# ...                     ...                            ...
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
# US                      NaN                            NaN
#
#         Attribute12_DataLength Attribute12_Nullable Attribute12_Concatenated
# BG
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# Canada                     NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# ...                        ...                  ...                      ...
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
# US                         NaN                  NaN                      NaN
#
# [333 rows x 141 columns]

# %%
summary = pd.DataFrame({'Feed Count': df.groupby(['BG', 'BU', 'Reqcategory', 'Typename', 'FinancialReportingRequirements', 'BUProposedStrategytoMeetRequirements'])['BUProposedStrategytoMeetRequirements'].count()}).reset_index()
summary
# Out:
#          BG              BU            Reqcategory                   Typename  \
# 0    Canada  Group Benefits                IFRS 17                 New GB EBF
# 1    Canada  Group Benefits                IFRS 17                 New GB EBF
# 2    Canada  Group Benefits                IFRS 17                 New GB EBF
# 3    Canada  Group Benefits                IFRS 17                 New GB EBF
# 4    Canada  Group Benefits                IFRS 17                 New GB EBF
# 5        US  Group Benefits  Additional Accounting  New US Ref Data (Benefit)
# 6        US  Group Benefits  Additional Accounting                 New US TBF
# 7        US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 8        US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 9        US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 10       US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 11       US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 12       US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 13       US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 14       US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 15       US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 16       US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 17       US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 18       US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 19       US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 20       US  Group Benefits   Additional Reporting  New US Ref Data (Benefit)
# 21       US  Group Benefits   Additional Reporting    New US Ref Data (Group)
# 22       US  Group Benefits   Additional Reporting    New US Ref Data (Group)
# 23       US  Group Benefits   Additional Reporting    New US Ref Data (Group)
# 24       US  Group Benefits   Additional Reporting    New US Ref Data (Group)
# 25       US  Group Benefits   Additional Reporting    New US Ref Data (Group)
# 26       US  Group Benefits   Additional Reporting    New US Ref Data (Group)
# 27       US  Group Benefits   Additional Reporting    New US Ref Data (Group)
# 28       US  Group Benefits   Additional Reporting    New US Ref Data (Group)
# 29       US  Group Benefits   Additional Reporting    New US Ref Data (Group)
# ..      ...             ...                    ...                        ...
# 133      US  Group Benefits                IFRS 17  New US Ref Data (Benefit)
# 134      US  Group Benefits                IFRS 17  New US Ref Data (Benefit)
# 135      US  Group Benefits                IFRS 17  New US Ref Data (Benefit)
# 136      US  Group Benefits                IFRS 17    New US Ref Data (Group)
# 137      US  Group Benefits                IFRS 17                 New US TBF
# 138      US  Group Benefits                IFRS 17                 New US TBF
# 139      US  Group Benefits                IFRS 17                 New US TBF
# 140      US  Group Benefits                IFRS 17                 New US TBF
# 141      US  Group Benefits                IFRS 17                 New US TBF
# 142      US  Group Benefits                IFRS 17                 New US TBF
# 143      US  Group Benefits                IFRS 17                 New US TBF
# 144      US  Group Benefits                IFRS 17                 New US TBF
# 145      US  Group Benefits                IFRS 17                 New US TBF
# 146      US  Group Benefits                IFRS 17                 New US TBF
# 147      US  Group Benefits                IFRS 17                 New US TBF
# 148      US  Group Benefits                IFRS 17                 New US TBF
# 149      US  Group Benefits                IFRS 17                 New US TBF
# 150      US  Group Benefits                IFRS 17                 New US TBF
# 151      US  Group Benefits                IFRS 17                 New US TBF
# 152      US  Group Benefits                IFRS 17                 New US TBF
# 153      US  Group Benefits                IFRS 17                 New US TBF
# 154      US  Group Benefits                IFRS 17                 New US TBF
# 155      US  Group Benefits                IFRS 17                 New US TBF
# 156      US  Group Benefits                IFRS 17                 New US TBF
# 157      US  Group Benefits                IFRS 17                 New US TBF
# 158      US  Group Benefits                IFRS 17                 New US TBF
# 159      US  Group Benefits                IFRS 17                 New US TBF
# 160      US  Group Benefits                IFRS 17                 New US TBF
# 161      US  Group Benefits                IFRS 17                 New US TBF
# 162      US  Group Benefits                IFRS 17                 New US TBF
#
#                         FinancialReportingRequirements  \
# 0                                               Cohort
# 1                                               Cohort
# 2                                            Portfolio
# 3                                            Portfolio
# 4                                            Portfolio
# 5                                         Legal Entity
# 6                                    Chart of Accounts
# 7                                           Agent ID 1
# 8                                           Agent ID 2
# 9                                  Benefit Expiry Date
# 10                              Benefit available date
# 11                                 Contract State Code
# 12                                         Create Date
# 13                                      Effective Date
# 14                                         Expiry Date
# 15                                 Parent Legal Entity
# 16                                     Policy Source 1
# 17                                     Policy Source 2
# 18                                     Policy Source 3
# 19                                     Policy Source 4
# 20                                             User ID
# 21                                            CRE Name
# 22                                Group Effective Date
# 23                                   Group Expiry Date
# 24                                        Group Office
# 25                                        Group Status
# 26                                          Group name
# 27                                          NAICS Code
# 28                                     Policy Source 1
# 29                                     Policy Source 2
# ..                                                 ...
# 133                              Rate Guarantee Period
# 134                                  Renewal Date Next
# 135                                 Renewal Date Prior
# 136  Date contract was issued (i.e. policy / benefi...
# 137        Account: Claims (e.g. Death, Annuity, etc.)
# 138   Account: Directly Attributable Acquisition Costs
# 139   Account: Directly Attributable Acquisition Costs
# 140                      Account: Investment Component
# 141    Account: Premiums (first year, renewal, single)
# 142    Account: Premiums (first year, renewal, single)
# 143  Cash flow indicator (Cash / Accrual / Adjustme...
# 144                                     Cohort / Group
# 145                                     Cohort / Group
# 146  Conversions: Indicator that policy is result o...
# 147  Conversions: Old Policy or Contract Number and...
# 148  Date contract matures (i.e. policy / benefit m...
# 149  Date contract matures (i.e. policy / benefit m...
# 150  Date contract was issued (i.e. policy / benefi...
# 151  Date contract was issued (i.e. policy / benefi...
# 152                                  Expense Indicator
# 153                                  Expense Indicator
# 154  How to uniquely identify contract? (i.e. polic...
# 155  How to uniquely identify contract? (i.e. polic...
# 156                              PAS System Identifier
# 157                                          Portfolio
# 158                                          Portfolio
# 159                          Reinsurance: Counterparty
# 160  Reinsurance: Date of initial recognition of ce...
# 161              Reinsurance: Direct underlying policy
# 162                             Reinsurance: Treaty ID
#
#     BUProposedStrategytoMeetRequirements  Feed Count
# 0                      Attribute in feed           1
# 1           Derived from feed attributes           4
# 2                      Attribute in feed           5
# 3           Derived from feed attributes           2
# 4                              Undecided           4
# 5                      Attribute in feed           1
# 6                      Attribute in feed           3
# 7                      Attribute in feed           1
# 8                      Attribute in feed           1
# 9                      Attribute in feed           1
# 10                     Attribute in feed           1
# 11                     Attribute in feed           1
# 12                     Attribute in feed           1
# 13                     Attribute in feed           1
# 14                     Attribute in feed           1
# 15                     Attribute in feed           1
# 16                     Attribute in feed           1
# 17                     Attribute in feed           1
# 18                     Attribute in feed           1
# 19                     Attribute in feed           1
# 20                     Attribute in feed           1
# 21                     Attribute in feed           1
# 22                     Attribute in feed           1
# 23                     Attribute in feed           1
# 24                     Attribute in feed           1
# 25                     Attribute in feed           1
# 26                     Attribute in feed           1
# 27                     Attribute in feed           1
# 28                     Attribute in feed           1
# 29                     Attribute in feed           1
# ..                                   ...         ...
# 133                    Attribute in feed           1
# 134                    Attribute in feed           1
# 135                    Attribute in feed           1
# 136                    Attribute in feed           1
# 137               Attribute not required           4
# 138               Attribute not required           3
# 139         Derived from feed attributes           1
# 140               Attribute not required           4
# 141               Attribute not required           2
# 142         Derived from feed attributes           2
# 143                    Attribute in feed           4
# 144               Attribute not required           2
# 145         Derived from feed attributes           2
# 146               Attribute not required           4
# 147               Attribute not required           4
# 148               Attribute not required           2
# 149                  Reference Data feed           2
# 150               Attribute not required           2
# 151                  Reference Data feed           2
# 152               Attribute not required           2
# 153         Derived from feed attributes           2
# 154               Attribute not required           1
# 155         Derived from feed attributes           3
# 156                    Attribute in feed           4
# 157               Attribute not required           2
# 158         Derived from feed attributes           2
# 159               Attribute not required           4
# 160               Attribute not required           4
# 161               Attribute not required           4
# 162               Attribute not required           4
#
# [163 rows x 7 columns]

# %%
file_types = df.Typename.unique()

file_types
# Out:
# array([u'New GB EBF', u'New US TBF', u'New US Ref Data (Group)',
#        u'New US Ref Data (Benefit)'], dtype=object)

# %%
# counts = df[df['Typename'].isin(["New GB EBF"])].PRKey.count()
# counts
attributes = df.FinancialReportingRequirements.unique()
attributes
attributes_count = {}
for j in file_types:
    nested = {}
    for i in attributes:
        name = df.loc[(df['Typename'].isin([j])) & (df['FinancialReportingRequirements'].isin([i]))]
        nested[i] = name.FinancialReportingRequirements.count()
    attributes_count[j] = nested

attributes_count
# Out:
# {u'New GB EBF': {u'Account Number': 0,
#   u'Account: Claims (e.g. Death, Annuity, etc.)': 0,
#   u'Account: Directly Attributable Acquisition Costs': 0,
#   u'Account: Investment Component': 0,
#   u'Account: Premiums (first year, renewal, single)': 0,
#   u'Accounting Bases of Feeds (i.e. IFRS 4, IFRS 17, USCAAP, etc.)': 0,
#   u'Agent ID 1': 0,
#   u'Agent ID 2': 0,
#   u'Amount': 0,
#   u'Approver ID': 0,
#   u'Associated Payee State Code': 0,
#   u'Bank Disbursement Date': 0,
#   u'Bank Disbursement Number': 0,
#   u'Bank EFT Originator ID': 0,
#   u'Bank Message': 0,
#   u'Basis Code': 0,
#   u'Benefit Expiry Date': 0,
#   u'Benefit available date': 0,
#   u'Benefit election date': 0,
#   u'Billing Unit 1': 0,
#   u'Billing Unit 2': 0,
#   u'Billing frequency': 0,
#   u'Book Date': 0,
#   u'Business Event Code 1': 0,
#   u'Business Event Code 2': 0,
#   u'Business Event Code 3': 0,
#   u'CRE Name': 0,
#   u'Cash flow indicator (Cash / Accrual / Adjustment, etc.)': 0,
#   u'Chart of Accounts': 0,
#   u'Claim ID 1': 0,
#   u'Claim ID 2': 0,
#   u'Claim incurral date': 0,
#   u'Claims reported date (aka claims start date)': 0,
#   u'Cohort': 5,
#   u'Cohort / Group': 0,
#   u'Contract State Code': 0,
#   u'Control Number 1': 0,
#   u'Control Number 2': 0,
#   u'Conversions: Indicator that policy is result of a conversion': 0,
#   u'Conversions: Old Policy or Contract Number and IFRS 17 Group': 0,
#   u'Cost Center': 0,
#   u'Create Date': 0,
#   u'Currency code': 0,
#   u'Date contract matures (i.e. policy / benefit maturity date)': 0,
#   u'Date contract was issued (i.e. policy / benefit issue date)': 0,
#   u'Debit/Credit Indicator': 0,
#   u'Effective Date': 0,
#   u'Expense Indicator': 0,
#   u'Expiry Date': 0,
#   u'Group Effective Date': 0,
#   u'Group Expiry Date': 0,
#   u'Group Office': 0,
#   u'Group Status': 0,
#   u'Group name': 0,
#   u'How to uniquely identify contract? (i.e. policy number)': 0,
#   u'Inter-company Indicator': 0,
#   u'Issue': 0,
#   u'Legal Entity': 0,
#   u'Major Product (segment/lob)': 0,
#   u'Major Product Source Code 1': 0,
#   u'Major Product Source Code 2': 0,
#   u'Major Product Source Code 3': 0,
#   u'Major Product Source Code 4': 0,
#   u'Major Product Source Code 5': 0,
#   u'Major Product Source Code 6': 0,
#   u'Member ID 1': 0,
#   u'Member ID 2': 0,
#   u'NAICS Code': 0,
#   u'PAS System Identifier': 0,
#   u'PRKey': 0,
#   u'Parent Legal Entity': 0,
#   u'Payee Name or Payee ID 1': 0,
#   u'Payee Name or Payee ID 2': 0,
#   u'Payee Name or Payee ID 3': 0,
#   u'Payee Tax ID': 0,
#   u'Policy Source 1': 0,
#   u'Policy Source 2': 0,
#   u'Policy Source 3': 0,
#   u'Policy Source 4': 0,
#   u'Portfolio': 11,
#   u'Preferred Partner': 0,
#   u'Primary Distributor': 0,
#   u'Rate Guarantee Period': 0,
#   u'Reinsurance Type Indicator': 0,
#   u'Reinsurance: Counterparty': 0,
#   u'Reinsurance: Date of initial recognition of cession': 0,
#   u'Reinsurance: Direct underlying policy': 0,
#   u'Reinsurance: Treaty ID': 0,
#   u'Renewal Date Next': 0,
#   u'Renewal Date Prior': 0,
#   u'Residence': 0,
#   u'Reversal Date': 0,
#   u'SIC Code': 0,
#   u'SITUS State': 0,
#   u'Sales Rep': 0,
#   u'Skip billing indicator': 0,
#   u'Skip period end date': 0,
#   u'Skip period start date': 0,
#   u'Source ID': 0,
#   u'Source System ID': 0,
#   u'Tax - street address 1': 0,
#   u'Tax - street address 2': 0,
#   u'Tax - street address 3': 0,
#   u'Tax Country Code': 0,
#   u'Tax County Code': 0,
#   u'Tax State Code': 0,
#   u'Tax city (e.g. muncipality)': 0,
#   u'Tax zip code': 0,
#   u'User ID': 0,
#   u'period end date': 0,
#   u'period start date': 0},
#  u'New US Ref Data (Benefit)': {u'Account Number': 0,
#   u'Account: Claims (e.g. Death, Annuity, etc.)': 0,
#   u'Account: Directly Attributable Acquisition Costs': 0,
#   u'Account: Investment Component': 0,
#   u'Account: Premiums (first year, renewal, single)': 0,
#   u'Accounting Bases of Feeds (i.e. IFRS 4, IFRS 17, USCAAP, etc.)': 0,
#   u'Agent ID 1': 1,
#   u'Agent ID 2': 1,
#   u'Amount': 0,
#   u'Approver ID': 0,
#   u'Associated Payee State Code': 0,
#   u'Bank Disbursement Date': 0,
#   u'Bank Disbursement Number': 0,
#   u'Bank EFT Originator ID': 0,
#   u'Bank Message': 0,
#   u'Basis Code': 0,
#   u'Benefit Expiry Date': 1,
#   u'Benefit available date': 1,
#   u'Benefit election date': 0,
#   u'Billing Unit 1': 0,
#   u'Billing Unit 2': 0,
#   u'Billing frequency': 0,
#   u'Book Date': 0,
#   u'Business Event Code 1': 0,
#   u'Business Event Code 2': 0,
#   u'Business Event Code 3': 0,
#   u'CRE Name': 0,
#   u'Cash flow indicator (Cash / Accrual / Adjustment, etc.)': 0,
#   u'Chart of Accounts': 0,
#   u'Claim ID 1': 0,
#   u'Claim ID 2': 0,
#   u'Claim incurral date': 0,
#   u'Claims reported date (aka claims start date)': 0,
#   u'Cohort': 0,
#   u'Cohort / Group': 0,
#   u'Contract State Code': 1,
#   u'Control Number 1': 0,
#   u'Control Number 2': 0,
#   u'Conversions: Indicator that policy is result of a conversion': 0,
#   u'Conversions: Old Policy or Contract Number and IFRS 17 Group': 0,
#   u'Cost Center': 0,
#   u'Create Date': 1,
#   u'Currency code': 0,
#   u'Date contract matures (i.e. policy / benefit maturity date)': 0,
#   u'Date contract was issued (i.e. policy / benefit issue date)': 0,
#   u'Debit/Credit Indicator': 0,
#   u'Effective Date': 1,
#   u'Expense Indicator': 0,
#   u'Expiry Date': 1,
#   u'Group Effective Date': 0,
#   u'Group Expiry Date': 0,
#   u'Group Office': 0,
#   u'Group Status': 0,
#   u'Group name': 0,
#   u'How to uniquely identify contract? (i.e. policy number)': 0,
#   u'Inter-company Indicator': 0,
#   u'Issue': 0,
#   u'Legal Entity': 1,
#   u'Major Product (segment/lob)': 0,
#   u'Major Product Source Code 1': 1,
#   u'Major Product Source Code 2': 1,
#   u'Major Product Source Code 3': 1,
#   u'Major Product Source Code 4': 1,
#   u'Major Product Source Code 5': 1,
#   u'Major Product Source Code 6': 1,
#   u'Member ID 1': 0,
#   u'Member ID 2': 0,
#   u'NAICS Code': 0,
#   u'PAS System Identifier': 0,
#   u'PRKey': 1,
#   u'Parent Legal Entity': 1,
#   u'Payee Name or Payee ID 1': 0,
#   u'Payee Name or Payee ID 2': 0,
#   u'Payee Name or Payee ID 3': 0,
#   u'Payee Tax ID': 0,
#   u'Policy Source 1': 1,
#   u'Policy Source 2': 1,
#   u'Policy Source 3': 1,
#   u'Policy Source 4': 1,
#   u'Portfolio': 0,
#   u'Preferred Partner': 0,
#   u'Primary Distributor': 0,
#   u'Rate Guarantee Period': 1,
#   u'Reinsurance Type Indicator': 1,
#   u'Reinsurance: Counterparty': 0,
#   u'Reinsurance: Date of initial recognition of cession': 0,
#   u'Reinsurance: Direct underlying policy': 0,
#   u'Reinsurance: Treaty ID': 0,
#   u'Renewal Date Next': 1,
#   u'Renewal Date Prior': 1,
#   u'Residence': 0,
#   u'Reversal Date': 0,
#   u'SIC Code': 0,
#   u'SITUS State': 0,
#   u'Sales Rep': 0,
#   u'Skip billing indicator': 0,
#   u'Skip period end date': 0,
#   u'Skip period start date': 0,
#   u'Source ID': 1,
#   u'Source System ID': 0,
#   u'Tax - street address 1': 0,
#   u'Tax - street address 2': 0,
#   u'Tax - street address 3': 0,
#   u'Tax Country Code': 0,
#   u'Tax County Code': 0,
#   u'Tax State Code': 0,
#   u'Tax city (e.g. muncipality)': 0,
#   u'Tax zip code': 0,
#   u'User ID': 1,
#   u'period end date': 0,
#   u'period start date': 0},
#  u'New US Ref Data (Group)': {u'Account Number': 0,
#   u'Account: Claims (e.g. Death, Annuity, etc.)': 0,
#   u'Account: Directly Attributable Acquisition Costs': 0,
#   u'Account: Investment Component': 0,
#   u'Account: Premiums (first year, renewal, single)': 0,
#   u'Accounting Bases of Feeds (i.e. IFRS 4, IFRS 17, USCAAP, etc.)': 0,
#   u'Agent ID 1': 0,
#   u'Agent ID 2': 0,
#   u'Amount': 0,
#   u'Approver ID': 0,
#   u'Associated Payee State Code': 0,
#   u'Bank Disbursement Date': 0,
#   u'Bank Disbursement Number': 0,
#   u'Bank EFT Originator ID': 0,
#   u'Bank Message': 0,
#   u'Basis Code': 0,
#   u'Benefit Expiry Date': 0,
#   u'Benefit available date': 0,
#   u'Benefit election date': 0,
#   u'Billing Unit 1': 0,
#   u'Billing Unit 2': 0,
#   u'Billing frequency': 0,
#   u'Book Date': 0,
#   u'Business Event Code 1': 0,
#   u'Business Event Code 2': 0,
#   u'Business Event Code 3': 0,
#   u'CRE Name': 1,
#   u'Cash flow indicator (Cash / Accrual / Adjustment, etc.)': 0,
#   u'Chart of Accounts': 0,
#   u'Claim ID 1': 0,
#   u'Claim ID 2': 0,
#   u'Claim incurral date': 0,
#   u'Claims reported date (aka claims start date)': 0,
#   u'Cohort': 0,
#   u'Cohort / Group': 0,
#   u'Contract State Code': 0,
#   u'Control Number 1': 0,
#   u'Control Number 2': 0,
#   u'Conversions: Indicator that policy is result of a conversion': 0,
#   u'Conversions: Old Policy or Contract Number and IFRS 17 Group': 0,
#   u'Cost Center': 0,
#   u'Create Date': 0,
#   u'Currency code': 0,
#   u'Date contract matures (i.e. policy / benefit maturity date)': 0,
#   u'Date contract was issued (i.e. policy / benefit issue date)': 1,
#   u'Debit/Credit Indicator': 0,
#   u'Effective Date': 0,
#   u'Expense Indicator': 0,
#   u'Expiry Date': 0,
#   u'Group Effective Date': 1,
#   u'Group Expiry Date': 1,
#   u'Group Office': 1,
#   u'Group Status': 1,
#   u'Group name': 1,
#   u'How to uniquely identify contract? (i.e. policy number)': 0,
#   u'Inter-company Indicator': 0,
#   u'Issue': 0,
#   u'Legal Entity': 0,
#   u'Major Product (segment/lob)': 0,
#   u'Major Product Source Code 1': 0,
#   u'Major Product Source Code 2': 0,
#   u'Major Product Source Code 3': 0,
#   u'Major Product Source Code 4': 0,
#   u'Major Product Source Code 5': 0,
#   u'Major Product Source Code 6': 0,
#   u'Member ID 1': 0,
#   u'Member ID 2': 0,
#   u'NAICS Code': 1,
#   u'PAS System Identifier': 0,
#   u'PRKey': 1,
#   u'Parent Legal Entity': 0,
#   u'Payee Name or Payee ID 1': 0,
#   u'Payee Name or Payee ID 2': 0,
#   u'Payee Name or Payee ID 3': 0,
#   u'Payee Tax ID': 0,
#   u'Policy Source 1': 1,
#   u'Policy Source 2': 1,
#   u'Policy Source 3': 1,
#   u'Policy Source 4': 1,
#   u'Portfolio': 0,
#   u'Preferred Partner': 1,
#   u'Primary Distributor': 1,
#   u'Rate Guarantee Period': 0,
#   u'Reinsurance Type Indicator': 0,
#   u'Reinsurance: Counterparty': 0,
#   u'Reinsurance: Date of initial recognition of cession': 0,
#   u'Reinsurance: Direct underlying policy': 0,
#   u'Reinsurance: Treaty ID': 0,
#   u'Renewal Date Next': 0,
#   u'Renewal Date Prior': 0,
#   u'Residence': 0,
#   u'Reversal Date': 0,
#   u'SIC Code': 1,
#   u'SITUS State': 1,
#   u'Sales Rep': 1,
#   u'Skip billing indicator': 0,
#   u'Skip period end date': 0,
#   u'Skip period start date': 0,
#   u'Source ID': 1,
#   u'Source System ID': 0,
#   u'Tax - street address 1': 1,
#   u'Tax - street address 2': 1,
#   u'Tax - street address 3': 0,
#   u'Tax Country Code': 1,
#   u'Tax County Code': 1,
#   u'Tax State Code': 1,
#   u'Tax city (e.g. muncipality)': 1,
#   u'Tax zip code': 1,
#   u'User ID': 1,
#   u'period end date': 0,
#   u'period start date': 0},
#  u'New US TBF': {u'Account Number': 3,
#   u'Account: Claims (e.g. Death, Annuity, etc.)': 4,
#   u'Account: Directly Attributable Acquisition Costs': 4,
#   u'Account: Investment Component': 4,
#   u'Account: Premiums (first year, renewal, single)': 4,
#   u'Accounting Bases of Feeds (i.e. IFRS 4, IFRS 17, USCAAP, etc.)': 3,
#   u'Agent ID 1': 3,
#   u'Agent ID 2': 3,
#   u'Amount': 3,
#   u'Approver ID': 3,
#   u'Associated Payee State Code': 3,
#   u'Bank Disbursement Date': 3,
#   u'Bank Disbursement Number': 3,
#   u'Bank EFT Originator ID': 3,
#   u'Bank Message': 3,
#   u'Basis Code': 3,
#   u'Benefit Expiry Date': 0,
#   u'Benefit available date': 0,
#   u'Benefit election date': 3,
#   u'Billing Unit 1': 3,
#   u'Billing Unit 2': 3,
#   u'Billing frequency': 3,
#   u'Book Date': 3,
#   u'Business Event Code 1': 3,
#   u'Business Event Code 2': 3,
#   u'Business Event Code 3': 3,
#   u'CRE Name': 0,
#   u'Cash flow indicator (Cash / Accrual / Adjustment, etc.)': 4,
#   u'Chart of Accounts': 3,
#   u'Claim ID 1': 3,
#   u'Claim ID 2': 3,
#   u'Claim incurral date': 3,
#   u'Claims reported date (aka claims start date)': 3,
#   u'Cohort': 0,
#   u'Cohort / Group': 4,
#   u'Contract State Code': 0,
#   u'Control Number 1': 3,
#   u'Control Number 2': 3,
#   u'Conversions: Indicator that policy is result of a conversion': 4,
#   u'Conversions: Old Policy or Contract Number and IFRS 17 Group': 4,
#   u'Cost Center': 3,
#   u'Create Date': 3,
#   u'Currency code': 3,
#   u'Date contract matures (i.e. policy / benefit maturity date)': 4,
#   u'Date contract was issued (i.e. policy / benefit issue date)': 4,
#   u'Debit/Credit Indicator': 3,
#   u'Effective Date': 3,
#   u'Expense Indicator': 4,
#   u'Expiry Date': 0,
#   u'Group Effective Date': 0,
#   u'Group Expiry Date': 0,
#   u'Group Office': 0,
#   u'Group Status': 0,
#   u'Group name': 0,
#   u'How to uniquely identify contract? (i.e. policy number)': 4,
#   u'Inter-company Indicator': 3,
#   u'Issue': 3,
#   u'Legal Entity': 3,
#   u'Major Product (segment/lob)': 3,
#   u'Major Product Source Code 1': 0,
#   u'Major Product Source Code 2': 0,
#   u'Major Product Source Code 3': 0,
#   u'Major Product Source Code 4': 0,
#   u'Major Product Source Code 5': 0,
#   u'Major Product Source Code 6': 0,
#   u'Member ID 1': 3,
#   u'Member ID 2': 3,
#   u'NAICS Code': 0,
#   u'PAS System Identifier': 4,
#   u'PRKey': 4,
#   u'Parent Legal Entity': 3,
#   u'Payee Name or Payee ID 1': 3,
#   u'Payee Name or Payee ID 2': 3,
#   u'Payee Name or Payee ID 3': 3,
#   u'Payee Tax ID': 3,
#   u'Policy Source 1': 3,
#   u'Policy Source 2': 3,
#   u'Policy Source 3': 3,
#   u'Policy Source 4': 3,
#   u'Portfolio': 4,
#   u'Preferred Partner': 0,
#   u'Primary Distributor': 0,
#   u'Rate Guarantee Period': 0,
#   u'Reinsurance Type Indicator': 4,
#   u'Reinsurance: Counterparty': 4,
#   u'Reinsurance: Date of initial recognition of cession': 4,
#   u'Reinsurance: Direct underlying policy': 4,
#   u'Reinsurance: Treaty ID': 4,
#   u'Renewal Date Next': 0,
#   u'Renewal Date Prior': 0,
#   u'Residence': 3,
#   u'Reversal Date': 3,
#   u'SIC Code': 0,
#   u'SITUS State': 0,
#   u'Sales Rep': 0,
#   u'Skip billing indicator': 3,
#   u'Skip period end date': 3,
#   u'Skip period start date': 3,
#   u'Source ID': 2,
#   u'Source System ID': 1,
#   u'Tax - street address 1': 3,
#   u'Tax - street address 2': 3,
#   u'Tax - street address 3': 3,
#   u'Tax Country Code': 0,
#   u'Tax County Code': 0,
#   u'Tax State Code': 0,
#   u'Tax city (e.g. muncipality)': 3,
#   u'Tax zip code': 3,
#   u'User ID': 3,
#   u'period end date': 3,
#   u'period start date': 3}}

# %%
summary['Percentage'] = ""
for file_type in attributes_count:
    for key in attributes_count[file_type]:
        new = summary.loc[(summary['Typename'].isin([file_type])) & (summary['FinancialReportingRequirements'].isin([key]))]
        new['Percentage'] = new['Feed Count'] / attributes_count[file_type][key] * 100
        summary.update(new)

summary
# Out:
# C:\Users\Jia.C.Chen\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#        BG              BU Reqcategory    Typename  \
# 0  Canada  Group Benefits     IFRS 17  New GB EBF
# 1  Canada  Group Benefits     IFRS 17  New GB EBF
# 2  Canada  Group Benefits     IFRS 17  New GB EBF
# 3  Canada  Group Benefits     IFRS 17  New GB EBF
# 4  Canada  Group Benefits     IFRS 17  New GB EBF
#
#   FinancialReportingRequirements BUProposedStrategytoMeetRequirements  \
# 0                         Cohort                    Attribute in feed
# 1                         Cohort         Derived from feed attributes
# 2                      Portfolio                    Attribute in feed
# 3                      Portfolio         Derived from feed attributes
# 4                      Portfolio                            Undecided
#
#    Feed Count Percentage
# 0         1.0         20
# 1         4.0         80
# 2         5.0    45.4545
# 3         2.0    18.1818
# 4         4.0    36.3636

# %%
summary.to_excel("summary.xlsx")
